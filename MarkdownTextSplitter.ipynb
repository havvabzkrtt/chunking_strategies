# %%
import langchain
from langchain.text_splitter import MarkdownTextSplitter

# %%
text = """ Paris: Fransa'nın Kalbi

Paris, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.

Paris'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.

Paris'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça ortaya çıkar.
"""

# %%
text   # \n\n : paragraflar split edilmiş
# Out:
# " Paris: Fransa'nın Kalbi\n\nParis, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça ortaya çıkar.\n"

# %%
# LatexTextSplitter nesnesini oluşturma
#markdown_splitter  = MarkdownTextSplitter(chunk_size=200, chunk_overlap = 20, length_function = len)
markdown_splitter  = MarkdownTextSplitter(chunk_size=200)

# %%
# Metni parçalara bölmek için split_text() metodunu kullanın
chunks = markdown_splitter .create_documents([text])

# %%
len(chunks)
# Out:
# 64

# %%
type(chunks)
# Out:
# list

# %%
for i, _ in enumerate(chunks):
    print(f"chunk # {i}, chunk: {chunks[i]}")
    print("--------------------------------------------")
# Out:
# chunk # 0, chunk: page_content="Paris: Fransa'nın Kalbi"
# --------------------------------------------
# chunk # 1, chunk: page_content="Paris, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem"
# --------------------------------------------
# chunk # 2, chunk: page_content="Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi,"
# --------------------------------------------
# chunk # 3, chunk: page_content="başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat"
# --------------------------------------------
# chunk # 4, chunk: page_content="ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve"
# --------------------------------------------
# chunk # 5, chunk: page_content="şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle"
# --------------------------------------------
# chunk # 6, chunk: page_content="olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya"
# --------------------------------------------
# chunk # 7, chunk: page_content="sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde"
# --------------------------------------------
# chunk # 8, chunk: page_content="bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük"
# --------------------------------------------
# chunk # 9, chunk: page_content="yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi"
# --------------------------------------------
# chunk # 10, chunk: page_content="aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor."
# --------------------------------------------
# chunk # 11, chunk: page_content="Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi"
# --------------------------------------------
# chunk # 12, chunk: page_content="kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel"
# --------------------------------------------
# chunk # 13, chunk: page_content="ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi"
# --------------------------------------------
# chunk # 14, chunk: page_content="kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame"
# --------------------------------------------
# chunk # 15, chunk: page_content="Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve"
# --------------------------------------------
# chunk # 16, chunk: page_content="Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre"
# --------------------------------------------
# chunk # 17, chunk: page_content='kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi'
# --------------------------------------------
# chunk # 18, chunk: page_content='yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge'
# --------------------------------------------
# chunk # 19, chunk: page_content='bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar,'
# --------------------------------------------
# chunk # 20, chunk: page_content="şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i"
# --------------------------------------------
# chunk # 21, chunk: page_content="muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan"
# --------------------------------------------
# chunk # 22, chunk: page_content="sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece"
# --------------------------------------------
# chunk # 23, chunk: page_content="ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır."
# --------------------------------------------
# chunk # 24, chunk: page_content="Paris'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş"
# --------------------------------------------
# chunk # 25, chunk: page_content="güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya"
# --------------------------------------------
# chunk # 26, chunk: page_content="sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in"
# --------------------------------------------
# chunk # 27, chunk: page_content="yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında"
# --------------------------------------------
# chunk # 28, chunk: page_content="sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir"
# --------------------------------------------
# chunk # 29, chunk: page_content="değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş"
# --------------------------------------------
# chunk # 30, chunk: page_content="şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak,"
# --------------------------------------------
# chunk # 31, chunk: page_content="sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in"
# --------------------------------------------
# chunk # 32, chunk: page_content="atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu"
# --------------------------------------------
# chunk # 33, chunk: page_content="de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli"
# --------------------------------------------
# chunk # 34, chunk: page_content="Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece"
# --------------------------------------------
# chunk # 35, chunk: page_content="gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır."
# --------------------------------------------
# chunk # 36, chunk: page_content="bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca,"
# --------------------------------------------
# chunk # 37, chunk: page_content="dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin"
# --------------------------------------------
# chunk # 38, chunk: page_content="Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi"
# --------------------------------------------
# chunk # 39, chunk: page_content="lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya"
# --------------------------------------------
# chunk # 40, chunk: page_content="mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının"
# --------------------------------------------
# chunk # 41, chunk: page_content="alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli"
# --------------------------------------------
# chunk # 42, chunk: page_content="veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini"
# --------------------------------------------
# chunk # 43, chunk: page_content="Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar."
# --------------------------------------------
# chunk # 44, chunk: page_content="Paris'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında"
# --------------------------------------------
# chunk # 45, chunk: page_content="en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak,"
# --------------------------------------------
# chunk # 46, chunk: page_content="büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in"
# --------------------------------------------
# chunk # 47, chunk: page_content="yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu"
# --------------------------------------------
# chunk # 48, chunk: page_content="biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini"
# --------------------------------------------
# chunk # 49, chunk: page_content="her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin"
# --------------------------------------------
# chunk # 50, chunk: page_content="romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece"
# --------------------------------------------
# chunk # 51, chunk: page_content="hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur."
# --------------------------------------------
# chunk # 52, chunk: page_content="Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler"
# --------------------------------------------
# chunk # 53, chunk: page_content="batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir"
# --------------------------------------------
# chunk # 54, chunk: page_content="Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya"
# --------------------------------------------
# chunk # 55, chunk: page_content="Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde,"
# --------------------------------------------
# chunk # 56, chunk: page_content="romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in"
# --------------------------------------------
# chunk # 57, chunk: page_content="bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten"
# --------------------------------------------
# chunk # 58, chunk: page_content="tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de"
# --------------------------------------------
# chunk # 59, chunk: page_content="yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın"
# --------------------------------------------
# chunk # 60, chunk: page_content="veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi"
# --------------------------------------------
# chunk # 61, chunk: page_content="Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu"
# --------------------------------------------
# chunk # 62, chunk: page_content="Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça"
# --------------------------------------------
# chunk # 63, chunk: page_content="ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça ortaya çıkar."
# --------------------------------------------

# %%
from PyPDF2 import PdfReader

# Bu fonksiyon, belirtilen PDF dosyasını açar, her sayfadaki metni çıkarır ve tüm metni birleştirerek tek bir metin dizesi olarak döndürür.
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as f:
        pdf_reader = PdfReader(f)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text


pdf_path = "documents/PDF.pdf"
pdf_text = extract_text_from_pdf(pdf_path)

# %%
# Şimdi RecursiveCharacterTextSplitter fonksiyonunu kullanarak metni parçalara bölün
chunks_pdf = markdown_splitter.create_documents([pdf_text])

# %%
len(chunks_pdf)
# Out:
# 1865

# %%
for i, _ in enumerate(chunks_pdf):
    print(f"chunk # {i}, chunk: {chunks_pdf[i]}")
    print("--------------------------------------------")
# Out:
# chunk # 0, chunk: page_content='Original Paper\nDesign Consider ations for an Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :'
# --------------------------------------------
# chunk # 1, chunk: page_content='Design Consider ations for an Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health'
# --------------------------------------------
# chunk # 2, chunk: page_content='Qualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews'
# --------------------------------------------
# chunk # 3, chunk: page_content='Care Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD'
# --------------------------------------------
# chunk # 4, chunk: page_content='1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland'
# --------------------------------------------
# chunk # 5, chunk: page_content='Zurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden'
# --------------------------------------------
# chunk # 6, chunk: page_content='3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc'
# --------------------------------------------
# chunk # 7, chunk: page_content='Corr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich'
# --------------------------------------------
# chunk # 8, chunk: page_content='Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland'
# --------------------------------------------
# chunk # 9, chunk: page_content='Technology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act'
# --------------------------------------------
# chunk # 10, chunk: page_content='Phone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most'
# --------------------------------------------
# chunk # 11, chunk: page_content='effective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume'
# --------------------------------------------
# chunk # 12, chunk: page_content='of training and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild'
# --------------------------------------------
# chunk # 13, chunk: page_content='neurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems'
# --------------------------------------------
# chunk # 14, chunk: page_content='of crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that'
# --------------------------------------------
# chunk # 15, chunk: page_content='includes end users throughout different iterati ve cycles of development.'
# --------------------------------------------
# chunk # 16, chunk: page_content='Objecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults'
# --------------------------------------------
# chunk # 17, chunk: page_content='with mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and training\ncomponents.'
# --------------------------------------------
# chunk # 18, chunk: page_content='components.\nMethods: A qualitati ve study including expert focus groups and individual semistructured in-depth patient intervie ws was'
# --------------------------------------------
# chunk # 19, chunk: page_content='conducted. Data were transcribed to a written format to perform qualitati ve content analysis using QCAmap softw are.'
# --------------------------------------------
# chunk # 20, chunk: page_content='Results: In total, 10 experts and health care professionals (80% females) and 8 older adults with mNCD (38% females; mean\nage 82.4, SD 6.2 years) were recruited until data saturation was observ ed.'
# --------------------------------------------
# chunk # 21, chunk: page_content='age 82.4, SD 6.2 years) were recruited until data saturation was observ ed.\nConclusions: The psychosocial consequences of patients’ self-percei ved cogniti ve deterioration might be more burdensome'
# --------------------------------------------
# chunk # 22, chunk: page_content='than the cogniti ve changes themselv es. Older adults with mNCD prefer integrative forms of training (such as exergaming) and'
# --------------------------------------------
# chunk # 23, chunk: page_content='are primarily motivated by enjoyment or fun in exercising and the effectiveness of the training. Putting the synthesized perspecti ves'
# --------------------------------------------
# chunk # 24, chunk: page_content='of training goals, settings, and requirements for exergames and training components into conte xt, our considerations point to'
# --------------------------------------------
# chunk # 25, chunk: page_content='opportunities for impro vement in research and rehabilitation, either by adapting existing exergames to patients with mNCDs or'
# --------------------------------------------
# chunk # 26, chunk: page_content='by developing novel exergames and exergame-based training concepts specif ically tailored to meet patient requirements and\nneeds.\n(JMIR Serious Games 2023;11:e37616) doi: 10.2196/37616\nKEYW ORDS'
# --------------------------------------------
# chunk # 27, chunk: page_content='needs.\n(JMIR Serious Games 2023;11:e37616) doi: 10.2196/37616\nKEYW ORDS\ncognition; exercise; exergame; design; development; neurosciences; technology; training'
# --------------------------------------------
# chunk # 28, chunk: page_content='KEYW ORDS\ncognition; exercise; exergame; design; development; neurosciences; technology; training\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 1 https://g ames.jmir .org/2023/1/e37616'
# --------------------------------------------
# chunk # 29, chunk: page_content='JMIR Serious Games 2023 | vol. 11 | e37616 | p. 1 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al JMIR SERIOUS GAMES\nXSL•FO\nRenderXIntroduction\nBackgr ound'
# --------------------------------------------
# chunk # 30, chunk: page_content='(page number not for citation purposes)Manser et al JMIR SERIOUS GAMES\nXSL•FO\nRenderXIntroduction\nBackgr ound\nThe normal aging process is associated with a decline in physical'
# --------------------------------------------
# chunk # 31, chunk: page_content='XSL•FO\nRenderXIntroduction\nBackgr ound\nThe normal aging process is associated with a decline in physical\nand cogniti ve abilities [1,2]. When the cogniti ve decline exceeds'
# --------------------------------------------
# chunk # 32, chunk: page_content='and cogniti ve abilities [1,2]. When the cogniti ve decline exceeds\nthe normal age-related cogniti ve decline but is not severe enough\nto interfere with independence in activities of daily living, it'
# --------------------------------------------
# chunk # 33, chunk: page_content='the normal age-related cogniti ve decline but is not severe enough\nto interfere with independence in activities of daily living, it\ncan be classif ied as “mild cogniti ve impairment” (MCI),'
# --------------------------------------------
# chunk # 34, chunk: page_content='to interfere with independence in activities of daily living, it\ncan be classif ied as “mild cogniti ve impairment” (MCI),\nrepresenting an intermediate stage of cogniti ve impairment'
# --------------------------------------------
# chunk # 35, chunk: page_content='can be classif ied as “mild cogniti ve impairment” (MCI),\nrepresenting an intermediate stage of cogniti ve impairment\nbetween the normal aging process and dementia [3-9]. The'
# --------------------------------------------
# chunk # 36, chunk: page_content='representing an intermediate stage of cogniti ve impairment\nbetween the normal aging process and dementia [3-9]. The\ncondition MCI has evolved over the last decades [5] and has'
# --------------------------------------------
# chunk # 37, chunk: page_content='between the normal aging process and dementia [3-9]. The\ncondition MCI has evolved over the last decades [5] and has\nrecently been incorporated in the latest Diagnostic and Statistical'
# --------------------------------------------
# chunk # 38, chunk: page_content='condition MCI has evolved over the last decades [5] and has\nrecently been incorporated in the latest Diagnostic and Statistical\nManual of Mental Disorders 5th Edition (DSM-5) and the'
# --------------------------------------------
# chunk # 39, chunk: page_content='recently been incorporated in the latest Diagnostic and Statistical\nManual of Mental Disorders 5th Edition (DSM-5) and the\nInternational Classif ication of Diseases 11th Revision, referred'
# --------------------------------------------
# chunk # 40, chunk: page_content='Manual of Mental Disorders 5th Edition (DSM-5) and the\nInternational Classif ication of Diseases 11th Revision, referred\nto as mild neurocogniti ve disorder (mNCD) [7,9-11]. The'
# --------------------------------------------
# chunk # 41, chunk: page_content='International Classif ication of Diseases 11th Revision, referred\nto as mild neurocogniti ve disorder (mNCD) [7,9-11]. The\nprevalence of mNCD increases with age, while the incidence'
# --------------------------------------------
# chunk # 42, chunk: page_content='to as mild neurocogniti ve disorder (mNCD) [7,9-11]. The\nprevalence of mNCD increases with age, while the incidence\nof mNCD and the progression to dementia is expected to rise,'
# --------------------------------------------
# chunk # 43, chunk: page_content='prevalence of mNCD increases with age, while the incidence\nof mNCD and the progression to dementia is expected to rise,\nlargely because of the globally growing life expectancies and'
# --------------------------------------------
# chunk # 44, chunk: page_content='of mNCD and the progression to dementia is expected to rise,\nlargely because of the globally growing life expectancies and\nsedentary lifestyles [3,5,12-15]. As currently no effective'
# --------------------------------------------
# chunk # 45, chunk: page_content='largely because of the globally growing life expectancies and\nsedentary lifestyles [3,5,12-15]. As currently no effective\npharmacological interv entions for patients with mNCD exist'
# --------------------------------------------
# chunk # 46, chunk: page_content='sedentary lifestyles [3,5,12-15]. As currently no effective\npharmacological interv entions for patients with mNCD exist\n[16], alternati ve options to prevent and treat neurocogniti ve'
# --------------------------------------------
# chunk # 47, chunk: page_content='pharmacological interv entions for patients with mNCD exist\n[16], alternati ve options to prevent and treat neurocogniti ve\ndisorders are needed. Targeting modif iable risk factors in midlife'
# --------------------------------------------
# chunk # 48, chunk: page_content='[16], alternati ve options to prevent and treat neurocogniti ve\ndisorders are needed. Targeting modif iable risk factors in midlife\nmay hold promise for mitig ating or even preventing'
# --------------------------------------------
# chunk # 49, chunk: page_content='disorders are needed. Targeting modif iable risk factors in midlife\nmay hold promise for mitig ating or even preventing\nneurocogniti ve disorders in later life [17-21]. The modif iable'
# --------------------------------------------
# chunk # 50, chunk: page_content='may hold promise for mitig ating or even preventing\nneurocogniti ve disorders in later life [17-21]. The modif iable\nrisk factors for mNCD include the presence of vascular risk'
# --------------------------------------------
# chunk # 51, chunk: page_content='neurocogniti ve disorders in later life [17-21]. The modif iable\nrisk factors for mNCD include the presence of vascular risk\nfactors (ie, metabolic syndrome, hypertension, hyperlipidemia,'
# --------------------------------------------
# chunk # 52, chunk: page_content='risk factors for mNCD include the presence of vascular risk\nfactors (ie, metabolic syndrome, hypertension, hyperlipidemia,\ncoronary heart disease, diabetes mellitus, or strok e) [22-24] or'
# --------------------------------------------
# chunk # 53, chunk: page_content='factors (ie, metabolic syndrome, hypertension, hyperlipidemia,\ncoronary heart disease, diabetes mellitus, or strok e) [22-24] or\na physically or cogniti vely sedentary lifestyle [25,26].'
# --------------------------------------------
# chunk # 54, chunk: page_content='coronary heart disease, diabetes mellitus, or strok e) [22-24] or\na physically or cogniti vely sedentary lifestyle [25,26].\nConsequently , changes in lifestyle that increase physical and'
# --------------------------------------------
# chunk # 55, chunk: page_content='a physically or cogniti vely sedentary lifestyle [25,26].\nConsequently , changes in lifestyle that increase physical and\ncogniti ve activity and reduce vascular risk factors are protecti ve'
# --------------------------------------------
# chunk # 56, chunk: page_content='Consequently , changes in lifestyle that increase physical and\ncogniti ve activity and reduce vascular risk factors are protecti ve\nagainst cogniti ve decline [27-35].'
# --------------------------------------------
# chunk # 57, chunk: page_content='cogniti ve activity and reduce vascular risk factors are protecti ve\nagainst cogniti ve decline [27-35].\nExergames have gained growing interest to prevent and treat'
# --------------------------------------------
# chunk # 58, chunk: page_content='against cogniti ve decline [27-35].\nExergames have gained growing interest to prevent and treat\nneurocogniti ve disorders [36-38]. “Exergaming is defined as'
# --------------------------------------------
# chunk # 59, chunk: page_content='Exergames have gained growing interest to prevent and treat\nneurocogniti ve disorders [36-38]. “Exergaming is defined as\ntechnology-dri ven physical activities, such as video game play,'
# --------------------------------------------
# chunk # 60, chunk: page_content='neurocogniti ve disorders [36-38]. “Exergaming is defined as\ntechnology-dri ven physical activities, such as video game play,\nthat requires participants to be physically active or exercise in'
# --------------------------------------------
# chunk # 61, chunk: page_content='technology-dri ven physical activities, such as video game play,\nthat requires participants to be physically active or exercise in\norder to play the game” [39]. One of the major advantages of'
# --------------------------------------------
# chunk # 62, chunk: page_content='that requires participants to be physically active or exercise in\norder to play the game” [39]. One of the major advantages of\nexergame-based training is that it is widely accepted by'
# --------------------------------------------
# chunk # 63, chunk: page_content='order to play the game” [39]. One of the major advantages of\nexergame-based training is that it is widely accepted by\nindividuals with neurocogniti ve disorders. In addition, it'
# --------------------------------------------
# chunk # 64, chunk: page_content='exergame-based training is that it is widely accepted by\nindividuals with neurocogniti ve disorders. In addition, it\nincreases training adherence and engagement by facilitating'
# --------------------------------------------
# chunk # 65, chunk: page_content='individuals with neurocogniti ve disorders. In addition, it\nincreases training adherence and engagement by facilitating\ntraining motivation and satisf action [40], which in turn may'
# --------------------------------------------
# chunk # 66, chunk: page_content='increases training adherence and engagement by facilitating\ntraining motivation and satisf action [40], which in turn may\nhave a positi ve effect on the effectiveness of impro ving'
# --------------------------------------------
# chunk # 67, chunk: page_content='training motivation and satisf action [40], which in turn may\nhave a positi ve effect on the effectiveness of impro ving\ncogniti ve functioning [41]. Furthermore, exergames can be used'
# --------------------------------------------
# chunk # 68, chunk: page_content='have a positi ve effect on the effectiveness of impro ving\ncogniti ve functioning [41]. Furthermore, exergames can be used\nas a form of simultaneous cogniti ve-motor training with'
# --------------------------------------------
# chunk # 69, chunk: page_content='cogniti ve functioning [41]. Furthermore, exergames can be used\nas a form of simultaneous cogniti ve-motor training with\nincorporated cogniti ve task demands [42]. Meta-analytic'
# --------------------------------------------
# chunk # 70, chunk: page_content='as a form of simultaneous cogniti ve-motor training with\nincorporated cogniti ve task demands [42]. Meta-analytic\nevidence suggests that simultaneous motor -cogniti ve training'
# --------------------------------------------
# chunk # 71, chunk: page_content='incorporated cogniti ve task demands [42]. Meta-analytic\nevidence suggests that simultaneous motor -cogniti ve training\nis the most effective type of training for impro ving cognition'
# --------------------------------------------
# chunk # 72, chunk: page_content='evidence suggests that simultaneous motor -cogniti ve training\nis the most effective type of training for impro ving cognition\nin health y older adults (HOA) [43,44] and older adults with'
# --------------------------------------------
# chunk # 73, chunk: page_content='is the most effective type of training for impro ving cognition\nin health y older adults (HOA) [43,44] and older adults with\nmNCD [44-46]. For exergames specif ically , a recent systematic'
# --------------------------------------------
# chunk # 74, chunk: page_content='in health y older adults (HOA) [43,44] and older adults with\nmNCD [44-46]. For exergames specif ically , a recent systematic\nreview synthesized evidence from low risk of bias studies'
# --------------------------------------------
# chunk # 75, chunk: page_content='mNCD [44-46]. For exergames specif ically , a recent systematic\nreview synthesized evidence from low risk of bias studies\nshowing that there were consistent positi ve effects favoring'
# --------------------------------------------
# chunk # 76, chunk: page_content='review synthesized evidence from low risk of bias studies\nshowing that there were consistent positi ve effects favoring\nexergaming in people with mNCD and dementia [40].'
# --------------------------------------------
# chunk # 77, chunk: page_content='showing that there were consistent positi ve effects favoring\nexergaming in people with mNCD and dementia [40].\nNonetheless, it is currently difficult to draw reliable conclusions'
# --------------------------------------------
# chunk # 78, chunk: page_content='exergaming in people with mNCD and dementia [40].\nNonetheless, it is currently difficult to draw reliable conclusions\nabout the effectiveness of exergaming in preventing and treating'
# --------------------------------------------
# chunk # 79, chunk: page_content='Nonetheless, it is currently difficult to draw reliable conclusions\nabout the effectiveness of exergaming in preventing and treating\nneurocogniti ve disorders because of the substantial variations'
# --------------------------------------------
# chunk # 80, chunk: page_content='about the effectiveness of exergaming in preventing and treating\nneurocogniti ve disorders because of the substantial variations\nin the exergame-based training used. Therefore, further'
# --------------------------------------------
# chunk # 81, chunk: page_content='neurocogniti ve disorders because of the substantial variations\nin the exergame-based training used. Therefore, further\ninvestig ations are needed for the establishment of effective'
# --------------------------------------------
# chunk # 82, chunk: page_content='in the exergame-based training used. Therefore, further\ninvestig ations are needed for the establishment of effective\nexergame and training components (ie, exercise and training'
# --------------------------------------------
# chunk # 83, chunk: page_content='exergame and training components (ie, exercise and training\nvariables such as the frequenc y, intensity , duration, or volumeof training and the type and content of specif ic exergame'
# --------------------------------------------
# chunk # 84, chunk: page_content='variables such as the frequenc y, intensity , duration, or volumeof training and the type and content of specif ic exergame\nscenarios) for cogniti ve functioning that can be applied with'
# --------------------------------------------
# chunk # 85, chunk: page_content='scenarios) for cogniti ve functioning that can be applied with\nconfidence in evidence-based exergame interv entions [36].\nRegarding the design and development of novel exergames, it'
# --------------------------------------------
# chunk # 86, chunk: page_content='confidence in evidence-based exergame interv entions [36].\nRegarding the design and development of novel exergames, it\nseems crucial to explicitly include the intended users’'
# --------------------------------------------
# chunk # 87, chunk: page_content='Regarding the design and development of novel exergames, it\nseems crucial to explicitly include the intended users’\nperspecti ves [47]. Taking the characteristics, needs, and'
# --------------------------------------------
# chunk # 88, chunk: page_content='seems crucial to explicitly include the intended users’\nperspecti ves [47]. Taking the characteristics, needs, and\nexperiences into account should ensure adequate use and'
# --------------------------------------------
# chunk # 89, chunk: page_content='perspecti ves [47]. Taking the characteristics, needs, and\nexperiences into account should ensure adequate use and\ntherefore the effectiveness of the solution. Baquero et al [48]'
# --------------------------------------------
# chunk # 90, chunk: page_content='experiences into account should ensure adequate use and\ntherefore the effectiveness of the solution. Baquero et al [48]\npointed out that an end user–centered methodological design is'
# --------------------------------------------
# chunk # 91, chunk: page_content='therefore the effectiveness of the solution. Baquero et al [48]\npointed out that an end user–centered methodological design is\nmost often adopted in the development of computer -based'
# --------------------------------------------
# chunk # 92, chunk: page_content='pointed out that an end user–centered methodological design is\nmost often adopted in the development of computer -based\ntraining programs for cogniti ve rehabilitation of older adults'
# --------------------------------------------
# chunk # 93, chunk: page_content='most often adopted in the development of computer -based\ntraining programs for cogniti ve rehabilitation of older adults\nwith neurocogniti ve disorders (NCDs). In an ideal case, this'
# --------------------------------------------
# chunk # 94, chunk: page_content='training programs for cogniti ve rehabilitation of older adults\nwith neurocogniti ve disorders (NCDs). In an ideal case, this\nprocess fulfills the international standards for the development'
# --------------------------------------------
# chunk # 95, chunk: page_content='with neurocogniti ve disorders (NCDs). In an ideal case, this\nprocess fulfills the international standards for the development\nof programs including (1) understanding and specifying the'
# --------------------------------------------
# chunk # 96, chunk: page_content='process fulfills the international standards for the development\nof programs including (1) understanding and specifying the\nconte xt of use (type, characteristics and tasks of users, and'
# --------------------------------------------
# chunk # 97, chunk: page_content='of programs including (1) understanding and specifying the\nconte xt of use (type, characteristics and tasks of users, and\nphysical or social environment), (2) specifying the user'
# --------------------------------------------
# chunk # 98, chunk: page_content='conte xt of use (type, characteristics and tasks of users, and\nphysical or social environment), (2) specifying the user\nrequirements, (3) producing design solutions, and (4) evaluating'
# --------------------------------------------
# chunk # 99, chunk: page_content='physical or social environment), (2) specifying the user\nrequirements, (3) producing design solutions, and (4) evaluating\nthe design [48,49]. So far, only half of the studies reporting'
# --------------------------------------------
# chunk # 100, chunk: page_content='requirements, (3) producing design solutions, and (4) evaluating\nthe design [48,49]. So far, only half of the studies reporting\ncomputer -based interv entions took the standard “specif ication'
# --------------------------------------------
# chunk # 101, chunk: page_content='the design [48,49]. So far, only half of the studies reporting\ncomputer -based interv entions took the standard “specif ication\nof user requirements” into account [48]. This has led to the'
# --------------------------------------------
# chunk # 102, chunk: page_content='computer -based interv entions took the standard “specif ication\nof user requirements” into account [48]. This has led to the\nrecommendation that future studies in this field should use an'
# --------------------------------------------
# chunk # 103, chunk: page_content='of user requirements” into account [48]. This has led to the\nrecommendation that future studies in this field should use an\ninteracti ve and participatory design that explicitly includes end'
# --------------------------------------------
# chunk # 104, chunk: page_content='recommendation that future studies in this field should use an\ninteracti ve and participatory design that explicitly includes end\nusers throughout different iterati ve cycles of development [48].'
# --------------------------------------------
# chunk # 105, chunk: page_content='interacti ve and participatory design that explicitly includes end\nusers throughout different iterati ve cycles of development [48].\nIn short, it is important to systematically and thoroughly'
# --------------------------------------------
# chunk # 106, chunk: page_content='users throughout different iterati ve cycles of development [48].\nIn short, it is important to systematically and thoroughly\ninvestig ate the specif ic user requirements and preferences for'
# --------------------------------------------
# chunk # 107, chunk: page_content='In short, it is important to systematically and thoroughly\ninvestig ate the specif ic user requirements and preferences for\nan exergame-based training concept before it is designed and\ndeveloped.'
# --------------------------------------------
# chunk # 108, chunk: page_content='investig ate the specif ic user requirements and preferences for\nan exergame-based training concept before it is designed and\ndeveloped.\nObjecti ves'
# --------------------------------------------
# chunk # 109, chunk: page_content='an exergame-based training concept before it is designed and\ndeveloped.\nObjecti ves\nThis study aimed to determine the capabilities, treatment'
# --------------------------------------------
# chunk # 110, chunk: page_content='developed.\nObjecti ves\nThis study aimed to determine the capabilities, treatment\npreferences, and motivators for the training of older adults with'
# --------------------------------------------
# chunk # 111, chunk: page_content='Objecti ves\nThis study aimed to determine the capabilities, treatment\npreferences, and motivators for the training of older adults with\nmNCD and the perspecti ves of individuals on training goals'
# --------------------------------------------
# chunk # 112, chunk: page_content='preferences, and motivators for the training of older adults with\nmNCD and the perspecti ves of individuals on training goals\nand settings and requirements for exergame and training\ncomponents.'
# --------------------------------------------
# chunk # 113, chunk: page_content='mNCD and the perspecti ves of individuals on training goals\nand settings and requirements for exergame and training\ncomponents.\nMethods\nOverview'
# --------------------------------------------
# chunk # 114, chunk: page_content='and settings and requirements for exergame and training\ncomponents.\nMethods\nOverview\nThis study is part of the national project “Brain-IT ,” which'
# --------------------------------------------
# chunk # 115, chunk: page_content='components.\nMethods\nOverview\nThis study is part of the national project “Brain-IT ,” which\nbegan in August 2020 in Switzerland. The aims of the overall'
# --------------------------------------------
# chunk # 116, chunk: page_content='Overview\nThis study is part of the national project “Brain-IT ,” which\nbegan in August 2020 in Switzerland. The aims of the overall\nproject are (1) to determine the most suitable components for'
# --------------------------------------------
# chunk # 117, chunk: page_content='began in August 2020 in Switzerland. The aims of the overall\nproject are (1) to determine the most suitable components for\nexergame-based training in older adults with mNCD; (2) to'
# --------------------------------------------
# chunk # 118, chunk: page_content='project are (1) to determine the most suitable components for\nexergame-based training in older adults with mNCD; (2) to\nexplore novel strate gies for a real-time adapti ve exergame'
# --------------------------------------------
# chunk # 119, chunk: page_content='exergame-based training in older adults with mNCD; (2) to\nexplore novel strate gies for a real-time adapti ve exergame\nsystem to individually tailor exergame demands according to'
# --------------------------------------------
# chunk # 120, chunk: page_content='explore novel strate gies for a real-time adapti ve exergame\nsystem to individually tailor exergame demands according to\nusers’ physical or cogniti ve capabilities; (3) to incorporate the'
# --------------------------------------------
# chunk # 121, chunk: page_content='system to individually tailor exergame demands according to\nusers’ physical or cogniti ve capabilities; (3) to incorporate the\nacquired knowledge into an exergame-based training concept'
# --------------------------------------------
# chunk # 122, chunk: page_content='users’ physical or cogniti ve capabilities; (3) to incorporate the\nacquired knowledge into an exergame-based training concept\nwith the aim of halting or reducing cogniti ve decline and'
# --------------------------------------------
# chunk # 123, chunk: page_content='acquired knowledge into an exergame-based training concept\nwith the aim of halting or reducing cogniti ve decline and\nimpro ving quality of life; and (4) to evaluate the effectiveness'
# --------------------------------------------
# chunk # 124, chunk: page_content='with the aim of halting or reducing cogniti ve decline and\nimpro ving quality of life; and (4) to evaluate the effectiveness\nof the resulting training interv ention in older adults with mNCD.'
# --------------------------------------------
# chunk # 125, chunk: page_content='impro ving quality of life; and (4) to evaluate the effectiveness\nof the resulting training interv ention in older adults with mNCD.\nThe project is guided by a theoretical frame work that provides'
# --------------------------------------------
# chunk # 126, chunk: page_content='of the resulting training interv ention in older adults with mNCD.\nThe project is guided by a theoretical frame work that provides\nspecif ic guidance in the design, development, and evaluation'
# --------------------------------------------
# chunk # 127, chunk: page_content='The project is guided by a theoretical frame work that provides\nspecif ic guidance in the design, development, and evaluation\nof exergames for older adults, the “Multidisciplinary Iterati ve'
# --------------------------------------------
# chunk # 128, chunk: page_content='specif ic guidance in the design, development, and evaluation\nof exergames for older adults, the “Multidisciplinary Iterati ve\nDesign of Exergames (MIDE): A Frame work for Supporting'
# --------------------------------------------
# chunk # 129, chunk: page_content='of exergames for older adults, the “Multidisciplinary Iterati ve\nDesign of Exergames (MIDE): A Frame work for Supporting\nthe Design, Development, and Evaluation of Exergames for'
# --------------------------------------------
# chunk # 130, chunk: page_content='Design of Exergames (MIDE): A Frame work for Supporting\nthe Design, Development, and Evaluation of Exergames for\nHealth” [50], which provides specif ic guidance in the design,'
# --------------------------------------------
# chunk # 131, chunk: page_content='the Design, Development, and Evaluation of Exergames for\nHealth” [50], which provides specif ic guidance in the design,\ndevelopment, and evaluation of exergames for older adults. This'
# --------------------------------------------
# chunk # 132, chunk: page_content='Health” [50], which provides specif ic guidance in the design,\ndevelopment, and evaluation of exergames for older adults. This\nstudy is part of the first phase of the project, with the aim to'
# --------------------------------------------
# chunk # 133, chunk: page_content='development, and evaluation of exergames for older adults. This\nstudy is part of the first phase of the project, with the aim to\nspecify a “set of design requirements that includes design'
# --------------------------------------------
# chunk # 134, chunk: page_content='study is part of the first phase of the project, with the aim to\nspecify a “set of design requirements that includes design\nconsiderations, accessibility recommendations, user modeling'
# --------------------------------------------
# chunk # 135, chunk: page_content='considerations, accessibility recommendations, user modeling\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 2 https://g ames.jmir .org/2023/1/e37616'
# --------------------------------------------
# chunk # 136, chunk: page_content='JMIR Serious Games 2023 | vol. 11 | e37616 | p. 2 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al JMIR SERIOUS GAMES\nXSL•FO'
# --------------------------------------------
# chunk # 137, chunk: page_content='(page number not for citation purposes)Manser et al JMIR SERIOUS GAMES\nXSL•FO\nRenderXelements, and technological reflections to be followed in the'
# --------------------------------------------
# chunk # 138, chunk: page_content='XSL•FO\nRenderXelements, and technological reflections to be followed in the\ndesign and development phase ”[47,50], and it was combined'
# --------------------------------------------
# chunk # 139, chunk: page_content='RenderXelements, and technological reflections to be followed in the\ndesign and development phase ”[47,50], and it was combined\nwith an extensi ve literature review and reflections on technology'
# --------------------------------------------
# chunk # 140, chunk: page_content='design and development phase ”[47,50], and it was combined\nwith an extensi ve literature review and reflections on technology\nscoping and sustainability strate gy (see steps 4 and 5 of phase'
# --------------------------------------------
# chunk # 141, chunk: page_content='with an extensi ve literature review and reflections on technology\nscoping and sustainability strate gy (see steps 4 and 5 of phase\n1 of our recently published methodological paper [47]). For the'
# --------------------------------------------
# chunk # 142, chunk: page_content='scoping and sustainability strate gy (see steps 4 and 5 of phase\n1 of our recently published methodological paper [47]). For the\nproject, the exergame device “Senso (Flex)” (Dividat AG) was'
# --------------------------------------------
# chunk # 143, chunk: page_content='1 of our recently published methodological paper [47]). For the\nproject, the exergame device “Senso (Flex)” (Dividat AG) was\npreselected on the basis of (1) our previous research, (2) because'
# --------------------------------------------
# chunk # 144, chunk: page_content='project, the exergame device “Senso (Flex)” (Dividat AG) was\npreselected on the basis of (1) our previous research, (2) because\nthis device has already been shown to be feasible and'
# --------------------------------------------
# chunk # 145, chunk: page_content='preselected on the basis of (1) our previous research, (2) because\nthis device has already been shown to be feasible and\nwell-accepted in geriatric patients [51] and patients with major'
# --------------------------------------------
# chunk # 146, chunk: page_content='this device has already been shown to be feasible and\nwell-accepted in geriatric patients [51] and patients with major\nneurocogniti ve disorder [52], and (3) because it is already widely'
# --------------------------------------------
# chunk # 147, chunk: page_content='well-accepted in geriatric patients [51] and patients with major\nneurocogniti ve disorder [52], and (3) because it is already widely\nused (and therefore available more widely and for longer term'
# --------------------------------------------
# chunk # 148, chunk: page_content='neurocogniti ve disorder [52], and (3) because it is already widely\nused (and therefore available more widely and for longer term\nby end users and health care institutions) for motor -cogniti ve'
# --------------------------------------------
# chunk # 149, chunk: page_content='used (and therefore available more widely and for longer term\nby end users and health care institutions) for motor -cogniti ve\ntraining within geriatric populations, physiotherapies, or'
# --------------------------------------------
# chunk # 150, chunk: page_content='by end users and health care institutions) for motor -cogniti ve\ntraining within geriatric populations, physiotherapies, or\nrehabilitation clinics in Switzerland. On this basis, this'
# --------------------------------------------
# chunk # 151, chunk: page_content='training within geriatric populations, physiotherapies, or\nrehabilitation clinics in Switzerland. On this basis, this\nqualitati ve study was designed to achie ve the defined objecti ves'
# --------------------------------------------
# chunk # 152, chunk: page_content='rehabilitation clinics in Switzerland. On this basis, this\nqualitati ve study was designed to achie ve the defined objecti ves\nin general; in addition, it also aimed to collect evidence about'
# --------------------------------------------
# chunk # 153, chunk: page_content='qualitati ve study was designed to achie ve the defined objecti ves\nin general; in addition, it also aimed to collect evidence about\nthe previous experiences of experts or health care professionals'
# --------------------------------------------
# chunk # 154, chunk: page_content='in general; in addition, it also aimed to collect evidence about\nthe previous experiences of experts or health care professionals\nwith different exergame systems [including the “Senso (Flex)”].'
# --------------------------------------------
# chunk # 155, chunk: page_content='the previous experiences of experts or health care professionals\nwith different exergame systems [including the “Senso (Flex)”].\nIn this way, the project team wanted to collect evidence to make'
# --------------------------------------------
# chunk # 156, chunk: page_content='with different exergame systems [including the “Senso (Flex)”].\nIn this way, the project team wanted to collect evidence to make\nan informed decision whether the specif ic exergame device was'
# --------------------------------------------
# chunk # 157, chunk: page_content='In this way, the project team wanted to collect evidence to make\nan informed decision whether the specif ic exergame device was\nsuitable for the project, what possible modif ications might be'
# --------------------------------------------
# chunk # 158, chunk: page_content='an informed decision whether the specif ic exergame device was\nsuitable for the project, what possible modif ications might be\nneeded to optimize the exergame experience for patients with'
# --------------------------------------------
# chunk # 159, chunk: page_content='suitable for the project, what possible modif ications might be\nneeded to optimize the exergame experience for patients with\nmNCD, and whether and what alternati ve exergame devices are'
# --------------------------------------------
# chunk # 160, chunk: page_content='needed to optimize the exergame experience for patients with\nmNCD, and whether and what alternati ve exergame devices are\nsuggested by the experts (see subsections of “(T2) Treatment'
# --------------------------------------------
# chunk # 161, chunk: page_content='mNCD, and whether and what alternati ve exergame devices are\nsuggested by the experts (see subsections of “(T2) Treatment\nExperience and Preferences—Pre vious Experiences with'
# --------------------------------------------
# chunk # 162, chunk: page_content='suggested by the experts (see subsections of “(T2) Treatment\nExperience and Preferences—Pre vious Experiences with\nExergames (‘Senso’ specif ically)” and “(T5) Exergame and'
# --------------------------------------------
# chunk # 163, chunk: page_content='Experience and Preferences—Pre vious Experiences with\nExergames (‘Senso’ specif ically)” and “(T5) Exergame and\nTraining Components—Ex ergame System and Content” in the'
# --------------------------------------------
# chunk # 164, chunk: page_content='Exergames (‘Senso’ specif ically)” and “(T5) Exergame and\nTraining Components—Ex ergame System and Content” in the\nfocus group discussions). Other than parts of these 2 sections'
# --------------------------------------------
# chunk # 165, chunk: page_content='Training Components—Ex ergame System and Content” in the\nfocus group discussions). Other than parts of these 2 sections\nthat include device-specif ic findings, none of the remaining'
# --------------------------------------------
# chunk # 166, chunk: page_content='focus group discussions). Other than parts of these 2 sections\nthat include device-specif ic findings, none of the remaining\nsections in this manuscript are device specif ic.\nStudy Design'
# --------------------------------------------
# chunk # 167, chunk: page_content='that include device-specif ic findings, none of the remaining\nsections in this manuscript are device specif ic.\nStudy Design\nA qualitati ve study was conducted between November 2020'
# --------------------------------------------
# chunk # 168, chunk: page_content='sections in this manuscript are device specif ic.\nStudy Design\nA qualitati ve study was conducted between November 2020\nand January 2021, including expert focus groups and patient'
# --------------------------------------------
# chunk # 169, chunk: page_content='Study Design\nA qualitati ve study was conducted between November 2020\nand January 2021, including expert focus groups and patient\nintervie ws; both were organized as semistructured, in-depth'
# --------------------------------------------
# chunk # 170, chunk: page_content='and January 2021, including expert focus groups and patient\nintervie ws; both were organized as semistructured, in-depth\nintervie ws. Semistructured, in-depth intervie ws are the most'
# --------------------------------------------
# chunk # 171, chunk: page_content='intervie ws; both were organized as semistructured, in-depth\nintervie ws. Semistructured, in-depth intervie ws are the most\nwidely used intervie wing format for qualitati ve research and'
# --------------------------------------------
# chunk # 172, chunk: page_content='intervie ws. Semistructured, in-depth intervie ws are the most\nwidely used intervie wing format for qualitati ve research and\nare generally organized around a set of predetermined'
# --------------------------------------------
# chunk # 173, chunk: page_content='widely used intervie wing format for qualitati ve research and\nare generally organized around a set of predetermined\nopen-ended questions, with additional questions and discussion'
# --------------------------------------------
# chunk # 174, chunk: page_content='are generally organized around a set of predetermined\nopen-ended questions, with additional questions and discussion\npoints emer ging from the dialogue [53]. The study was planned'
# --------------------------------------------
# chunk # 175, chunk: page_content='open-ended questions, with additional questions and discussion\npoints emer ging from the dialogue [53]. The study was planned\nand reported in accordance with the “consolidated criteria for'
# --------------------------------------------
# chunk # 176, chunk: page_content='points emer ging from the dialogue [53]. The study was planned\nand reported in accordance with the “consolidated criteria for\nreporting qualitati ve research (COREQ)” [54].'
# --------------------------------------------
# chunk # 177, chunk: page_content='and reported in accordance with the “consolidated criteria for\nreporting qualitati ve research (COREQ)” [54].\nThe MIDE Frame work [50] guided our approach. On the basis'
# --------------------------------------------
# chunk # 178, chunk: page_content='reporting qualitati ve research (COREQ)” [54].\nThe MIDE Frame work [50] guided our approach. On the basis\nof this frame work, we integrated multiple stakeholders into the'
# --------------------------------------------
# chunk # 179, chunk: page_content='The MIDE Frame work [50] guided our approach. On the basis\nof this frame work, we integrated multiple stakeholders into the\ndesign and development process including exergaming'
# --------------------------------------------
# chunk # 180, chunk: page_content='of this frame work, we integrated multiple stakeholders into the\ndesign and development process including exergaming\nresearchers, clinical experts with different backgrounds, a'
# --------------------------------------------
# chunk # 181, chunk: page_content='design and development process including exergaming\nresearchers, clinical experts with different backgrounds, a\ncompan y representing the exergaming industry , and the end\nusers.\nEthics Approval'
# --------------------------------------------
# chunk # 182, chunk: page_content='compan y representing the exergaming industry , and the end\nusers.\nEthics Approval\nAll the study procedures were performed in accordance with'
# --------------------------------------------
# chunk # 183, chunk: page_content='users.\nEthics Approval\nAll the study procedures were performed in accordance with\nthe Declaration of Helsinki. The study protocol (not registered)was appro ved by the ETH Zürich Ethics Commission (EK'
# --------------------------------------------
# chunk # 184, chunk: page_content='the Declaration of Helsinki. The study protocol (not registered)was appro ved by the ETH Zürich Ethics Commission (EK\n2020-N-154). All interested individuals were fully informed of'
# --------------------------------------------
# ...
# chunk # 1794, chunk: page_content='dwelling older adults: a formati ve one group quasi- experimental feasibility trial. Front Physiol 2019 Aug 7;10:1019 [FREE\nFull text] [doi: 10.3389/fph ys.2019.01019 ] [Medline: 31440168 ]'
# --------------------------------------------
# chunk # 1795, chunk: page_content='Full text] [doi: 10.3389/fph ys.2019.01019 ] [Medline: 31440168 ]\n85. Huber SK, Held JP, de Bruin ED, Knols RH. Personalized motor -cogniti ve exergame training in chronic strok e patients-a'
# --------------------------------------------
# chunk # 1796, chunk: page_content='feasibility study . Front Aging Neurosci 2021 Oct 20;13:730801 [FREE Full text] [doi: 10.3389/fnagi.2021.730801 ] [Medline:\n34744688 ]'
# --------------------------------------------
# chunk # 1797, chunk: page_content='34744688 ]\n86. Schättin A, Häfliger S, Meyer A, Früh B, Böckler S, Hungerb ühler Y, et al. Design and evaluation of user-centered exergames'
# --------------------------------------------
# chunk # 1798, chunk: page_content='for patients with multiple sclerosis: multile vel usability and feasibility studies. JMIR Serious Games 2021 May 07;9(2):e22826\n[FREE Full text] [doi: 10.2196/22826 ] [Medline: 33960956 ]'
# --------------------------------------------
# chunk # 1799, chunk: page_content='[FREE Full text] [doi: 10.2196/22826 ] [Medline: 33960956 ]\n87. Subramanian S, Dahl Y, Skjæret Maroni N, Vereijk en B, Svanæs D. Assessing motivational differences between young'
# --------------------------------------------
# chunk # 1800, chunk: page_content='and older adults when playing an exergame. Games Health J 2020 Feb 01;9(1):24-30. [doi: 10.1089/g4h.2019.0082 ]\n[Medline: 31532235 ]'
# --------------------------------------------
# chunk # 1801, chunk: page_content='[Medline: 31532235 ]\n88. Di Lorito C, Pollock K, Harw ood R, das Nair R, Logan P, Goldber g S, et al. A scoping review of behaviour change theories'
# --------------------------------------------
# chunk # 1802, chunk: page_content="in adults without dementia to adapt and develop the 'PHYT in dementia', a model promoting physical activity in people"
# --------------------------------------------
# chunk # 1803, chunk: page_content='with dementia. Maturitas 2019 Mar;121:101-113 [FREE Full text] [doi: 10.1016/j.maturitas.2019.01.008 ] [Medline:\n30686623 ]'
# --------------------------------------------
# chunk # 1804, chunk: page_content='30686623 ]\n89. Russell KL, Bray SR. Self-determined motivation predicts independent, home-based exercise following cardiac rehabilitation.'
# --------------------------------------------
# chunk # 1805, chunk: page_content='Rehabil Psychol 2009 May;54(2):150-156. [doi: 10.1037/a0015595 ] [Medline: 19469604 ]'
# --------------------------------------------
# chunk # 1806, chunk: page_content='90. Smith GE, Chandler M, Fields JA, Aakre J, Lock e DE. A survey of patient and partner outcome and treatment preferences'
# --------------------------------------------
# chunk # 1807, chunk: page_content='in mild cogniti ve impairment. J Alzheimer Dis 2018 May 30;63(4):1459-1468. [doi: 10.3233/jad-171161 ]'
# --------------------------------------------
# chunk # 1808, chunk: page_content='91. Amjad I, Toor H, Niazi IK, Pervaiz S, Jochumsen M, Shafique M, et al. Xbox 360 kinect cogniti ve games impro ve slowness,'
# --------------------------------------------
# chunk # 1809, chunk: page_content='comple xity of EEG, and cogniti ve functions in subjects with mild cogniti ve impairment: a randomized control trial. Games'
# --------------------------------------------
# chunk # 1810, chunk: page_content='Health J 2019 Apr;8(2):144-152. [doi: 10.1089/g4h.2018.0029 ] [Medline: 30239213 ]\n92. Anderson-Hanle y C, Barcelos NM, Zimmerman EA, Gillen RW, Dunnam M, Cohen BD, et al. The aerobic and cogniti ve'
# --------------------------------------------
# chunk # 1811, chunk: page_content='exercise study (ACES) for community-dwelling older adults with or at-risk for mild cogniti ve impairment (MCI):'
# --------------------------------------------
# chunk # 1812, chunk: page_content='neuropsychological, neurobiological and neuroimaging outcomes of a randomized clinical trial. Front Aging Neurosci 2018'
# --------------------------------------------
# chunk # 1813, chunk: page_content='May 4;10:76 [FREE Full text] [doi: 10.3389/fnagi.2018.00076 ] [Medline: 29780318 ]'
# --------------------------------------------
# chunk # 1814, chunk: page_content='93. Anderson-Hanle y C, Stark J, Wall KM, VanBrakle M, Michel M, Malone y M, et al. CIA 2018 Sep;V olume 13:1565-1577.\n[doi: 10.2147/cia.s160756 ]'
# --------------------------------------------
# chunk # 1815, chunk: page_content='[doi: 10.2147/cia.s160756 ]\n94. Delbroek T, Verme ylen W, Spildooren J. The effect of cogniti ve-motor dual task training with the biorescue force platform'
# --------------------------------------------
# chunk # 1816, chunk: page_content='on cognition, balance and dual task performance in institutionalized older adults: a randomized controlled trial. J Phys Ther'
# --------------------------------------------
# chunk # 1817, chunk: page_content='Sci 2017 Jul;29(7):1137-1143 [FREE Full text] [doi: 10.1589/jpts.29.1137 ] [Medline: 28744033 ]'
# --------------------------------------------
# chunk # 1818, chunk: page_content='95. Jirayucharoensak S, Israsena P, Pan-ngum S, Hemrungrojn S, Maes M. A game-based neurofeedback training system to'
# --------------------------------------------
# chunk # 1819, chunk: page_content='enhance cogniti ve performance in health y elderly subjects and in patients with amnestic mild cogniti ve impairment. Clin\nInterv Aging 2019 Feb;V olume 14:347-360. [doi: 10.2147/cia.s189047 ]'
# --------------------------------------------
# chunk # 1820, chunk: page_content='Interv Aging 2019 Feb;V olume 14:347-360. [doi: 10.2147/cia.s189047 ]\n96. Combourieu Donnezan L, Perrot A, Belle ville S, Bloch F, Kemoun G. Effects of simultaneous aerobic and cogniti ve training'
# --------------------------------------------
# chunk # 1821, chunk: page_content='on executi ve functions, cardio vascular fitness and functional abilities in older adults with mild cogniti ve impairment. Mental'
# --------------------------------------------
# chunk # 1822, chunk: page_content='Health Physical Activity 2018 Oct;15:78-87. [doi: 10.1016/j.mhpa.2018.06.001 ]'
# --------------------------------------------
# chunk # 1823, chunk: page_content='97. Ben-Sadoun G, Sacco G, Manera V, Bour geois J, König A, Foulon P, et al. Physical and cogniti ve stimulation using an'
# --------------------------------------------
# chunk # 1824, chunk: page_content='exergame in subjects with normal aging, mild and moderate cogniti ve impairment. J Alzheimer Dis 2016 Aug\n08;53(4):1299-1314. [doi: 10.3233/jad-160268 ]'
# --------------------------------------------
# chunk # 1825, chunk: page_content='08;53(4):1299-1314. [doi: 10.3233/jad-160268 ]\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 22 https://g ames.jmir .org/2023/1/e37616'
# --------------------------------------------
# chunk # 1826, chunk: page_content='JMIR Serious Games 2023 | vol. 11 | e37616 | p. 22 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al JMIR SERIOUS GAMES\nXSL•FO'
# --------------------------------------------
# chunk # 1827, chunk: page_content='XSL•FO\nRenderX98. Mrakic-Sposta S, Di Santo SG, Franchini F, Arlati S, Zangiacomi A, Greci L, et al. Effects of combined physical and'
# --------------------------------------------
# chunk # 1828, chunk: page_content='cogniti ve virtual reality-based training on cogniti ve impairment and oxidati ve stress in MCI patients: a pilot study . Front'
# --------------------------------------------
# chunk # 1829, chunk: page_content='Aging Neurosci 2018 Oct 1;10:282 [FREE Full text] [doi: 10.3389/fnagi.2018.00282 ] [Medline: 30327596 ]'
# --------------------------------------------
# chunk # 1830, chunk: page_content='99. Robert P, Albrengues C, Fabre R, Derreumaux A, Pancrazi MP, Luporsi I, et al. Efficacy of serious exergames in impro ving'
# --------------------------------------------
# chunk # 1831, chunk: page_content='neuropsychiatric symptoms in neurocogniti ve disorders: results of the X-TORP cluster randomized trial. Alzheimers Dement'
# --------------------------------------------
# chunk # 1832, chunk: page_content='(N Y) 2021;7(1):e12149 [FREE Full text] [doi: 10.1002/trc2.12149 ] [Medline: 34013018 ]'
# --------------------------------------------
# chunk # 1833, chunk: page_content='100. Wall K, Stark J, Schillaci A, Saulnier E, McLaren E, Striegnitz K, et al. The enhanced interacti ve physical and cogniti ve'
# --------------------------------------------
# chunk # 1834, chunk: page_content='exercise system (iPACES v2.0): pilot clinical trial of an in-home iPad-based neuro-e xergame for mild cogniti ve impairment'
# --------------------------------------------
# chunk # 1835, chunk: page_content='(MCI). J Clin Med 2018 Aug 30;7(9):249 [FREE Full text] [doi: 10.3390/jcm7090249 ] [Medline: 30200183 ]'
# --------------------------------------------
# chunk # 1836, chunk: page_content='101. Sanders LM, Hortobágyi T, la Bastide-v an Gemert S, van der Zee EA, van Heuv elen MJ. Dose-response relationship'
# --------------------------------------------
# chunk # 1837, chunk: page_content='between exercise and cogniti ve function in older adults with and without cogniti ve impairment: a systematic review and'
# --------------------------------------------
# chunk # 1838, chunk: page_content='meta-analysis. PLoS One 2019 Jan 10;14(1):e0210036 [FREE Full text] [doi: 10.1371/journal.pone.0210036 ] [Medline:\n30629631 ]'
# --------------------------------------------
# chunk # 1839, chunk: page_content='30629631 ]\n102. Bahar -Fuchs A, Martyr A, Goh AM, Sabates J, Clare L. Cogniti ve training for people with mild to moderate dementia.'
# --------------------------------------------
# chunk # 1840, chunk: page_content='Cochrane Database Syst Rev 2019 Mar 25;3(3):CD013069 [FREE Full text] [doi: 10.1002/14651858.CD013069.pub2 ]\n[Medline: 30909318 ]'
# --------------------------------------------
# chunk # 1841, chunk: page_content='[Medline: 30909318 ]\n103. Northe y JM, Cherb uin N, Pumpa KL, Smee DJ, Rattray B. Exercise interv entions for cogniti ve function in adults older'
# --------------------------------------------
# chunk # 1842, chunk: page_content='than 50: a systematic review with meta-analysis. Br J Sports Med 2018 Feb 24;52(3):154-160. [doi:\n10.1136/bjsports-2016-096587 ] [Medline: 28438770 ]'
# --------------------------------------------
# chunk # 1843, chunk: page_content='10.1136/bjsports-2016-096587 ] [Medline: 28438770 ]\n104. Butler M, McCreedy E, Nelson VA, Desai P, Ratner E, Fink HA, et al. Does cogniti ve training prevent cogniti ve decline?'
# --------------------------------------------
# chunk # 1844, chunk: page_content='104. Butler M, McCreedy E, Nelson VA, Desai P, Ratner E, Fink HA, et al. Does cogniti ve training prevent cogniti ve decline?\nAnn Intern Med 2017 Dec 19;168(1):63. [doi: 10.7326/m17-1531 ]'
# --------------------------------------------
# chunk # 1845, chunk: page_content='Ann Intern Med 2017 Dec 19;168(1):63. [doi: 10.7326/m17-1531 ]\n105. Toril P, Reales JM, Ballesteros S. Video game training enhances cognition of older adults: a meta-analytic study . Psychol'
# --------------------------------------------
# chunk # 1846, chunk: page_content='Aging 2014 Sep;29(3):706-716. [doi: 10.1037/a0037507 ] [Medline: 25244488 ]\nAbbreviations\nADL: activities of daily living\nCCT : computerized cogniti ve training'
# --------------------------------------------
# chunk # 1847, chunk: page_content='Abbreviations\nADL: activities of daily living\nCCT : computerized cogniti ve training\nDSM-5: Diagnostic and Statistical Manual of Mental Disorders 5th Edition\nHOA: health y older adults'
# --------------------------------------------
# chunk # 1848, chunk: page_content='CCT : computerized cogniti ve training\nDSM-5: Diagnostic and Statistical Manual of Mental Disorders 5th Edition\nHOA: health y older adults\nMCI: mild cogniti ve impairment'
# --------------------------------------------
# chunk # 1849, chunk: page_content='DSM-5: Diagnostic and Statistical Manual of Mental Disorders 5th Edition\nHOA: health y older adults\nMCI: mild cogniti ve impairment\nMIDE: Multidisciplinary Iterati ve Design of Exergames'
# --------------------------------------------
# chunk # 1850, chunk: page_content='HOA: health y older adults\nMCI: mild cogniti ve impairment\nMIDE: Multidisciplinary Iterati ve Design of Exergames\nmNCD: mild neurocogniti ve disorder\nMTT : medical training therap y'
# --------------------------------------------
# chunk # 1851, chunk: page_content='MCI: mild cogniti ve impairment\nMIDE: Multidisciplinary Iterati ve Design of Exergames\nmNCD: mild neurocogniti ve disorder\nMTT : medical training therap y\nNCD: neurocogniti ve disorders'
# --------------------------------------------
# chunk # 1852, chunk: page_content='MIDE: Multidisciplinary Iterati ve Design of Exergames\nmNCD: mild neurocogniti ve disorder\nMTT : medical training therap y\nNCD: neurocogniti ve disorders\nPT: physical therap y'
# --------------------------------------------
# chunk # 1853, chunk: page_content='NCD: neurocogniti ve disorders\nPT: physical therap y\nEdited by N Zary; submitted 28.02.22; peer-reviewed by MJ Brouillette , P Backlund; comments to author 12.06.22; revised version'
# --------------------------------------------
# chunk # 1854, chunk: page_content='Edited by N Zary; submitted 28.02.22; peer-reviewed by MJ Brouillette , P Backlund; comments to author 12.06.22; revised version\nreceived 28.06.22; accepted 10.10.22; published 05.01.23'
# --------------------------------------------
# chunk # 1855, chunk: page_content='received 28.06.22; accepted 10.10.22; published 05.01.23\nPlease cite as:\nManser P, Adcoc k-Omlin M, de Bruin ED'
# --------------------------------------------
# chunk # 1856, chunk: page_content='Please cite as:\nManser P, Adcoc k-Omlin M, de Bruin ED\nDesign Consider ations for an Exergame-Based Training Intervention for Older Adults With Mild Neur ocognitive Disor der: Qualitative'
# --------------------------------------------
# chunk # 1857, chunk: page_content='Study Including Focus Groups With Experts and Health Care Professionals and Individual Semistructur ed In-depth Patient Intervie ws\nJMIR Serious Games 2023;11:e37616'
# --------------------------------------------
# chunk # 1858, chunk: page_content='JMIR Serious Games 2023;11:e37616\nURL: https://games.jmir .org/2023/1/e37616\ndoi: 10.2196/37616\nPMID: 36602851'
# --------------------------------------------
# chunk # 1859, chunk: page_content='doi: 10.2196/37616\nPMID: 36602851\n©Patrick Manser , Manuela Adcock-Omlin, Eling D de Bruin. Originally published in JMIR Serious Games (https://g ames.jmir .org),'
# --------------------------------------------
# chunk # 1860, chunk: page_content='05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License'
# --------------------------------------------
# chunk # 1861, chunk: page_content='(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,'
# --------------------------------------------
# chunk # 1862, chunk: page_content='provided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a'
# --------------------------------------------
# chunk # 1863, chunk: page_content='link to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.'
# --------------------------------------------
# chunk # 1864, chunk: page_content='JMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al JMIR SERIOUS GAMES\nXSL•FO\nRenderX'
# --------------------------------------------

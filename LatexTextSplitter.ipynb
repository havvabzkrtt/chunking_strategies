# %%
import langchain
from langchain.text_splitter import LatexTextSplitter

# %%
text = """ Paris: Fransa'nın Kalbi

Paris, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.

Paris'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.

Paris'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça ortaya çıkar.
"""

# %%
text   # \n\n : paragraflar split edilmiş
# Out:
# " Paris: Fransa'nın Kalbi\n\nParis, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça ortaya çıkar.\n"

# %%
# LatexTextSplitter nesnesini oluşturma
# latex_splitter = LatexTextSplitter(chunk_size=200, chunk_overlap = 20, length_function = len)
latex_splitter = LatexTextSplitter(chunk_size=200)

# %%
# Metni parçalara bölmek için split_text() metodunu kullanın
chunks = latex_splitter.create_documents([text])

# %%
len(chunks)
# Out:
# 95

# %%
type(chunks)
# Out:
# list

# %%
for i, _ in enumerate(chunks):
    print(f"chunk # {i}, chunk: {chunks[i]}")
    print("--------------------------------------------")
# Out:
# chunk # 0, chunk: page_content="Paris: Fransa'nın Kalbi\n\nParis, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu"
# --------------------------------------------
# chunk # 1, chunk: page_content="Fransa'nın Kalbi\n\nParis, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici"
# --------------------------------------------
# chunk # 2, chunk: page_content="Kalbi\n\nParis, Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir,"
# --------------------------------------------
# chunk # 3, chunk: page_content="Fransa'nın başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi,"
# --------------------------------------------
# chunk # 4, chunk: page_content="başkenti ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat"
# --------------------------------------------
# chunk # 5, chunk: page_content="ve en büyük şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve"
# --------------------------------------------
# chunk # 6, chunk: page_content="şehri olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle"
# --------------------------------------------
# chunk # 7, chunk: page_content="olarak sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya"
# --------------------------------------------
# chunk # 8, chunk: page_content="sadece bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde"
# --------------------------------------------
# chunk # 9, chunk: page_content="bir yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük"
# --------------------------------------------
# chunk # 10, chunk: page_content="yer değil, aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi"
# --------------------------------------------
# chunk # 11, chunk: page_content="aynı zamanda Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor."
# --------------------------------------------
# chunk # 12, chunk: page_content="Fransız kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi"
# --------------------------------------------
# chunk # 13, chunk: page_content="kültürünün ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel"
# --------------------------------------------
# chunk # 14, chunk: page_content="ve tarihinin kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi"
# --------------------------------------------
# chunk # 15, chunk: page_content="kalbidir. Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame"
# --------------------------------------------
# chunk # 16, chunk: page_content="Seine Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve"
# --------------------------------------------
# chunk # 17, chunk: page_content="Nehri'nin kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre"
# --------------------------------------------
# chunk # 18, chunk: page_content='kıyısında yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi'
# --------------------------------------------
# chunk # 19, chunk: page_content='yer alan bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge'
# --------------------------------------------
# chunk # 20, chunk: page_content='bu büyüleyici şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar,'
# --------------------------------------------
# chunk # 21, chunk: page_content="şehir, muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i"
# --------------------------------------------
# chunk # 22, chunk: page_content="muhteşem mimarisi, sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan"
# --------------------------------------------
# chunk # 23, chunk: page_content="sanat eserleri ve romantizmiyle dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece"
# --------------------------------------------
# chunk # 24, chunk: page_content="dünya genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in"
# --------------------------------------------
# chunk # 25, chunk: page_content="genelinde büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri"
# --------------------------------------------
# chunk # 26, chunk: page_content="büyük ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece"
# --------------------------------------------
# chunk # 27, chunk: page_content="ilgi görüyor. Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla"
# --------------------------------------------
# chunk # 28, chunk: page_content="Efsanevi Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı"
# --------------------------------------------
# chunk # 29, chunk: page_content="Eiffel Kulesi, tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin"
# --------------------------------------------
# chunk # 30, chunk: page_content="tarihi Notre-Dame Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki"
# --------------------------------------------
# chunk # 31, chunk: page_content="Katedrali ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de"
# --------------------------------------------
# chunk # 32, chunk: page_content="ve Louvre Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir."
# --------------------------------------------
# chunk # 33, chunk: page_content="Müzesi gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre"
# --------------------------------------------
# chunk # 34, chunk: page_content="gibi simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi"
# --------------------------------------------
# chunk # 35, chunk: page_content="simge yapılar, Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem"
# --------------------------------------------
# chunk # 36, chunk: page_content="Paris'i benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde"
# --------------------------------------------
# chunk # 37, chunk: page_content="benzersiz kılan unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak,"
# --------------------------------------------
# chunk # 38, chunk: page_content="unsurlardan sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki"
# --------------------------------------------
# chunk # 39, chunk: page_content="sadece birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks"
# --------------------------------------------
# chunk # 40, chunk: page_content="birkaçıdır.\n\nParis'in güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda"
# --------------------------------------------
# chunk # 41, chunk: page_content="güzellikleri sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya"
# --------------------------------------------
# chunk # 42, chunk: page_content="sadece yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in"
# --------------------------------------------
# chunk # 43, chunk: page_content="yapılarla sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında"
# --------------------------------------------
# chunk # 44, chunk: page_content="sınırlı değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir"
# --------------------------------------------
# chunk # 45, chunk: page_content="değildir; şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş"
# --------------------------------------------
# chunk # 46, chunk: page_content="şehrin sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak,"
# --------------------------------------------
# chunk # 47, chunk: page_content="sokaklarındaki atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in"
# --------------------------------------------
# chunk # 48, chunk: page_content="atmosfer de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu"
# --------------------------------------------
# chunk # 49, chunk: page_content="de benzersizdir. Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli"
# --------------------------------------------
# chunk # 50, chunk: page_content="Montmartre gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece"
# --------------------------------------------
# chunk # 51, chunk: page_content="gibi bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır."
# --------------------------------------------
# chunk # 52, chunk: page_content="bohem bölgelerde dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca,"
# --------------------------------------------
# chunk # 53, chunk: page_content="dolaşmak, Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin"
# --------------------------------------------
# chunk # 54, chunk: page_content="Champs-Élysées'deki lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi"
# --------------------------------------------
# chunk # 55, chunk: page_content="lüks mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya"
# --------------------------------------------
# chunk # 56, chunk: page_content="mağazalarda alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının"
# --------------------------------------------
# chunk # 57, chunk: page_content="alışveriş yapmak veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli"
# --------------------------------------------
# chunk # 58, chunk: page_content="veya Seine'in kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini"
# --------------------------------------------
# chunk # 59, chunk: page_content="kıyısında romantik bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en"
# --------------------------------------------
# chunk # 60, chunk: page_content="bir yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici"
# --------------------------------------------
# chunk # 61, chunk: page_content="yürüyüş yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından"
# --------------------------------------------
# chunk # 62, chunk: page_content="yapmak, Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri"
# --------------------------------------------
# chunk # 63, chunk: page_content="Paris'in sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her"
# --------------------------------------------
# chunk # 64, chunk: page_content="sunduğu çeşitli deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede"
# --------------------------------------------
# chunk # 65, chunk: page_content="deneyimlerden sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin"
# --------------------------------------------
# chunk # 66, chunk: page_content="sadece birkaçıdır. Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün"
# --------------------------------------------
# chunk # 67, chunk: page_content="Ayrıca, şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine"
# --------------------------------------------
# chunk # 68, chunk: page_content="şehrin zengin gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde"
# --------------------------------------------
# chunk # 69, chunk: page_content="gastronomi sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir"
# --------------------------------------------
# chunk # 70, chunk: page_content="sahnesi, dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi"
# --------------------------------------------
# chunk # 71, chunk: page_content="dünya mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak"
# --------------------------------------------
# chunk # 72, chunk: page_content="mutfağının en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya"
# --------------------------------------------
# chunk # 73, chunk: page_content="en lezzetli örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles"
# --------------------------------------------
# chunk # 74, chunk: page_content="örneklerini sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde"
# --------------------------------------------
# chunk # 75, chunk: page_content="sunar.\n\nParis'in en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında"
# --------------------------------------------
# chunk # 76, chunk: page_content="en büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak,"
# --------------------------------------------
# chunk # 77, chunk: page_content="büyüleyici yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in"
# --------------------------------------------
# chunk # 78, chunk: page_content="yanlarından biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu"
# --------------------------------------------
# chunk # 79, chunk: page_content="biri de, her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini"
# --------------------------------------------
# chunk # 80, chunk: page_content="her köşede romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin"
# --------------------------------------------
# chunk # 81, chunk: page_content="romantizminin hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece"
# --------------------------------------------
# chunk # 82, chunk: page_content="hissedilmesidir. Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur."
# --------------------------------------------
# chunk # 83, chunk: page_content="Gün batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler"
# --------------------------------------------
# chunk # 84, chunk: page_content="batımında Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir"
# --------------------------------------------
# chunk # 85, chunk: page_content="Seine Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya"
# --------------------------------------------
# chunk # 86, chunk: page_content="Nehri'nde romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde,"
# --------------------------------------------
# chunk # 87, chunk: page_content="romantik bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in"
# --------------------------------------------
# chunk # 88, chunk: page_content="bir tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten"
# --------------------------------------------
# chunk # 89, chunk: page_content="tekne gezisi yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de"
# --------------------------------------------
# chunk # 90, chunk: page_content="yapmak veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın"
# --------------------------------------------
# chunk # 91, chunk: page_content="veya Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi"
# --------------------------------------------
# chunk # 92, chunk: page_content="Versailles Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu"
# --------------------------------------------
# chunk # 93, chunk: page_content="Bahçeleri'nde ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça"
# --------------------------------------------
# chunk # 94, chunk: page_content="ay ışığında dolaşmak, Paris'in aşk dolu atmosferini keşfetmenin sadece birkaç yoludur. Tüm bu özellikler bir araya geldiğinde, Paris'in gerçekten de Fransa'nın kalbi olduğu açıkça ortaya çıkar."
# --------------------------------------------

# %%
from PyPDF2 import PdfReader

# Bu fonksiyon, belirtilen PDF dosyasını açar, her sayfadaki metni çıkarır ve tüm metni birleştirerek tek bir metin dizesi olarak döndürür.
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as f:
        pdf_reader = PdfReader(f)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text


pdf_path = "documents/PDF.pdf"
pdf_text = extract_text_from_pdf(pdf_path)

# %%
# Şimdi RecursiveCharacterTextSplitter fonksiyonunu kullanarak metni parçalara bölün
chunks_pdf = latex_splitter.create_documents([pdf_text])

# %%
len(chunks_pdf)
# Out:
# 12612

# %%
for i, _ in enumerate(chunks_pdf):
    print(f"chunk # {i}, chunk: {chunks_pdf[i]}")
    print("--------------------------------------------")
# Out:
# chunk # 0, chunk: page_content='Original Paper\nDesign Consider ations for an Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and'
# --------------------------------------------
# chunk # 1, chunk: page_content='Paper\nDesign Consider ations for an Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare'
# --------------------------------------------
# chunk # 2, chunk: page_content='Consider ations for an Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals'
# --------------------------------------------
# chunk # 3, chunk: page_content='ations for an Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and'
# --------------------------------------------
# chunk # 4, chunk: page_content='for an Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual'
# --------------------------------------------
# chunk # 5, chunk: page_content='Exergame-Based Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr'
# --------------------------------------------
# chunk # 6, chunk: page_content='Training\nIntervention for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured'
# --------------------------------------------
# chunk # 7, chunk: page_content='for Older Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth'
# --------------------------------------------
# chunk # 8, chunk: page_content='Adults With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick'
# --------------------------------------------
# chunk # 9, chunk: page_content='With Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1,'
# --------------------------------------------
# chunk # 10, chunk: page_content='Mild Neurocognitiv e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc;'
# --------------------------------------------
# chunk # 11, chunk: page_content='e Disorder :\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela'
# --------------------------------------------
# chunk # 12, chunk: page_content=':\nQualitativ e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc;'
# --------------------------------------------
# chunk # 13, chunk: page_content='e Study Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de'
# --------------------------------------------
# chunk # 14, chunk: page_content='Including Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3,'
# --------------------------------------------
# chunk # 15, chunk: page_content='Focus Groups With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor'
# --------------------------------------------
# chunk # 16, chunk: page_content='With Exper ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and'
# --------------------------------------------
# chunk # 17, chunk: page_content='ts and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning'
# --------------------------------------------
# chunk # 18, chunk: page_content='and Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group'
# --------------------------------------------
# chunk # 19, chunk: page_content='Health\nCare Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group –'
# --------------------------------------------
# chunk # 20, chunk: page_content='Professionals and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of'
# --------------------------------------------
# chunk # 21, chunk: page_content='and Individual Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement'
# --------------------------------------------
# chunk # 22, chunk: page_content='Semistr uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and'
# --------------------------------------------
# chunk # 23, chunk: page_content='uctured In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport,'
# --------------------------------------------
# chunk # 24, chunk: page_content='In-depth Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department'
# --------------------------------------------
# chunk # 25, chunk: page_content='Patient\nInterviews\nPatrick Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of'
# --------------------------------------------
# chunk # 26, chunk: page_content='Manser1, MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology ,'
# --------------------------------------------
# chunk # 27, chunk: page_content='MSc; Manuela Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH'
# --------------------------------------------
# chunk # 28, chunk: page_content='Adcock-Omlin1, DSc; Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich,'
# --------------------------------------------
# chunk # 29, chunk: page_content='Eling D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division'
# --------------------------------------------
# chunk # 30, chunk: page_content='D de Bruin1,2,3, PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of'
# --------------------------------------------
# chunk # 31, chunk: page_content='PhD\n1Motor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y,'
# --------------------------------------------
# chunk # 32, chunk: page_content='Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of'
# --------------------------------------------
# chunk # 33, chunk: page_content='Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology'
# --------------------------------------------
# chunk # 34, chunk: page_content='Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care'
# --------------------------------------------
# chunk # 35, chunk: page_content='Institute of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences'
# --------------------------------------------
# chunk # 36, chunk: page_content='of Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and'
# --------------------------------------------
# chunk # 37, chunk: page_content='Human Movement Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society ,'
# --------------------------------------------
# chunk # 38, chunk: page_content='Sciences and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska'
# --------------------------------------------
# chunk # 39, chunk: page_content='and Sport, Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet,'
# --------------------------------------------
# chunk # 40, chunk: page_content='Department of Health Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm,'
# --------------------------------------------
# chunk # 41, chunk: page_content='Sciences and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of'
# --------------------------------------------
# chunk # 42, chunk: page_content='and Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health,'
# --------------------------------------------
# chunk # 43, chunk: page_content='Technology , ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST'
# --------------------------------------------
# chunk # 44, chunk: page_content=', ETH Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern'
# --------------------------------------------
# chunk # 45, chunk: page_content='Zurich,\nZurich, Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss'
# --------------------------------------------
# chunk # 46, chunk: page_content='Switzerland\n2Division of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of'
# --------------------------------------------
# chunk # 47, chunk: page_content='of Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences,'
# --------------------------------------------
# chunk # 48, chunk: page_content='Physiotherap y, Department of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen,'
# --------------------------------------------
# chunk # 49, chunk: page_content='of Neurobiology , Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding'
# --------------------------------------------
# chunk # 50, chunk: page_content=', Care Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick'
# --------------------------------------------
# chunk # 51, chunk: page_content='Sciences and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser'
# --------------------------------------------
# chunk # 52, chunk: page_content='and Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser ,'
# --------------------------------------------
# chunk # 53, chunk: page_content='Society , Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor'
# --------------------------------------------
# chunk # 54, chunk: page_content=', Karolinska Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control'
# --------------------------------------------
# chunk # 55, chunk: page_content='Institutet, Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning'
# --------------------------------------------
# chunk # 56, chunk: page_content='Stockholm, Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group –'
# --------------------------------------------
# chunk # 57, chunk: page_content='Sweden\n3Department of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of'
# --------------------------------------------
# chunk # 58, chunk: page_content='of Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement'
# --------------------------------------------
# chunk # 59, chunk: page_content='Health, OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences'
# --------------------------------------------
# chunk # 60, chunk: page_content='OST – Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and'
# --------------------------------------------
# chunk # 61, chunk: page_content='– Eastern Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport,'
# --------------------------------------------
# chunk # 62, chunk: page_content='Swiss University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department'
# --------------------------------------------
# chunk # 63, chunk: page_content='University of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of'
# --------------------------------------------
# chunk # 64, chunk: page_content='of Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health'
# --------------------------------------------
# chunk # 65, chunk: page_content='Applied Sciences, St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences'
# --------------------------------------------
# chunk # 66, chunk: page_content='St.Gallen, Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology ,'
# --------------------------------------------
# chunk # 67, chunk: page_content='Switzerland\nCorr esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH'
# --------------------------------------------
# chunk # 68, chunk: page_content='esponding Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W'
# --------------------------------------------
# chunk # 69, chunk: page_content='Author:\nPatrick Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4,'
# --------------------------------------------
# chunk # 70, chunk: page_content='Manser , MSc\nMotor Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich,'
# --------------------------------------------
# chunk # 71, chunk: page_content='Control and Learning Group – Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich,'
# --------------------------------------------
# chunk # 72, chunk: page_content='– Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41'
# --------------------------------------------
# chunk # 73, chunk: page_content='Institute of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79'
# --------------------------------------------
# chunk # 74, chunk: page_content='of Human Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96'
# --------------------------------------------
# chunk # 75, chunk: page_content='Movement Sciences and Sport, Department of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail:'
# --------------------------------------------
# chunk # 76, chunk: page_content='of Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr'
# --------------------------------------------
# chunk # 77, chunk: page_content='Health Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr'
# --------------------------------------------
# chunk # 78, chunk: page_content='Sciences and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound:'
# --------------------------------------------
# chunk # 79, chunk: page_content='and\nTechnology , ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames'
# --------------------------------------------
# chunk # 80, chunk: page_content=', ETH Zurich\nLeopold-Ruzicka-W eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted'
# --------------------------------------------
# chunk # 81, chunk: page_content='eg 4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the'
# --------------------------------------------
# chunk # 82, chunk: page_content='4, CH-8093 Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention'
# --------------------------------------------
# chunk # 83, chunk: page_content='Zurich, Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and'
# --------------------------------------------
# chunk # 84, chunk: page_content='Switzerland\nZurich, CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of'
# --------------------------------------------
# chunk # 85, chunk: page_content='CH-8093\nSwitzerland\nPhone: 41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve'
# --------------------------------------------
# chunk # 86, chunk: page_content='41 79 519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective'
# --------------------------------------------
# chunk # 87, chunk: page_content='519 96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame'
# --------------------------------------------
# chunk # 88, chunk: page_content='96 46\nEmail: patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and'
# --------------------------------------------
# chunk # 89, chunk: page_content='patrick.manser@hest.ethz.ch\nAbstr act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training'
# --------------------------------------------
# chunk # 90, chunk: page_content='act\nBackgr ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training'
# --------------------------------------------
# chunk # 91, chunk: page_content='ound: Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables'
# --------------------------------------------
# chunk # 92, chunk: page_content='Exergames have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such'
# --------------------------------------------
# chunk # 93, chunk: page_content='have attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc'
# --------------------------------------------
# chunk # 94, chunk: page_content='attracted growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y,'
# --------------------------------------------
# chunk # 95, chunk: page_content='growing interest in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity ,'
# --------------------------------------------
# chunk # 96, chunk: page_content='in the prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or'
# --------------------------------------------
# chunk # 97, chunk: page_content='prevention and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof'
# --------------------------------------------
# chunk # 98, chunk: page_content='and treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training'
# --------------------------------------------
# chunk # 99, chunk: page_content='treatment of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and'
# --------------------------------------------
# chunk # 100, chunk: page_content='of neurocogniti ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and'
# --------------------------------------------
# chunk # 101, chunk: page_content='ve disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif'
# --------------------------------------------
# chunk # 102, chunk: page_content='disorders. The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic'
# --------------------------------------------
# chunk # 103, chunk: page_content='The most\neffective exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame'
# --------------------------------------------
# chunk # 104, chunk: page_content='exergame and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however'
# --------------------------------------------
# chunk # 105, chunk: page_content='and training components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be'
# --------------------------------------------
# chunk # 106, chunk: page_content='components (ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established'
# --------------------------------------------
# chunk # 107, chunk: page_content='(ie, exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older'
# --------------------------------------------
# chunk # 108, chunk: page_content='exercise and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older adults'
# --------------------------------------------
# chunk # 109, chunk: page_content='and training variables such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older adults with'
# --------------------------------------------
# chunk # 110, chunk: page_content='such as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve'
# --------------------------------------------
# chunk # 111, chunk: page_content='as frequenc y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders'
# --------------------------------------------
# chunk # 112, chunk: page_content='y, intensity , duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs).'
# --------------------------------------------
# chunk # 113, chunk: page_content=', duration, or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the'
# --------------------------------------------
# chunk # 114, chunk: page_content='or volume\nof training and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and'
# --------------------------------------------
# chunk # 115, chunk: page_content='training and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of'
# --------------------------------------------
# chunk # 116, chunk: page_content='and type and content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel'
# --------------------------------------------
# chunk # 117, chunk: page_content='content of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based'
# --------------------------------------------
# chunk # 118, chunk: page_content='of specif ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training'
# --------------------------------------------
# chunk # 119, chunk: page_content='ic exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts,'
# --------------------------------------------
# chunk # 120, chunk: page_content='exergame scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it'
# --------------------------------------------
# chunk # 121, chunk: page_content='scenarios) however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof'
# --------------------------------------------
# chunk # 122, chunk: page_content='however remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial'
# --------------------------------------------
# chunk # 123, chunk: page_content='remain to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance'
# --------------------------------------------
# chunk # 124, chunk: page_content='to be established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to'
# --------------------------------------------
# chunk # 125, chunk: page_content='established for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly'
# --------------------------------------------
# chunk # 126, chunk: page_content='for older adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the'
# --------------------------------------------
# chunk # 127, chunk: page_content='adults with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended'
# --------------------------------------------
# chunk # 128, chunk: page_content='with mild\nneurocogniti ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’'
# --------------------------------------------
# chunk # 129, chunk: page_content='ve disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting'
# --------------------------------------------
# chunk # 130, chunk: page_content='disorders (mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an'
# --------------------------------------------
# chunk # 131, chunk: page_content='(mNCDs). Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti'
# --------------------------------------------
# chunk # 132, chunk: page_content='Regarding the design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and'
# --------------------------------------------
# chunk # 133, chunk: page_content='design and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory'
# --------------------------------------------
# chunk # 134, chunk: page_content='and development of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design'
# --------------------------------------------
# chunk # 135, chunk: page_content='of novel exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end'
# --------------------------------------------
# chunk # 136, chunk: page_content='exergame-based training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users'
# --------------------------------------------
# chunk # 137, chunk: page_content='training concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout'
# --------------------------------------------
# chunk # 138, chunk: page_content='concepts, it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different'
# --------------------------------------------
# chunk # 139, chunk: page_content='it seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve'
# --------------------------------------------
# chunk # 140, chunk: page_content='seems\nof crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles'
# --------------------------------------------
# chunk # 141, chunk: page_content='crucial importance to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of'
# --------------------------------------------
# chunk # 142, chunk: page_content='to explicitly include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve:'
# --------------------------------------------
# chunk # 143, chunk: page_content='include the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study'
# --------------------------------------------
# chunk # 144, chunk: page_content='the intended users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to'
# --------------------------------------------
# chunk # 145, chunk: page_content='users’ perspecti ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the'
# --------------------------------------------
# chunk # 146, chunk: page_content='ve by adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities,'
# --------------------------------------------
# chunk # 147, chunk: page_content='adopting an interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment'
# --------------------------------------------
# chunk # 148, chunk: page_content='interacti ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences,'
# --------------------------------------------
# chunk # 149, chunk: page_content='ve and participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and'
# --------------------------------------------
# chunk # 150, chunk: page_content='participatory design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators'
# --------------------------------------------
# chunk # 151, chunk: page_content='design that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the'
# --------------------------------------------
# chunk # 152, chunk: page_content='that\nincludes end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of'
# --------------------------------------------
# chunk # 153, chunk: page_content='end users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older'
# --------------------------------------------
# chunk # 154, chunk: page_content='users throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith'
# --------------------------------------------
# chunk # 155, chunk: page_content='throughout different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and'
# --------------------------------------------
# chunk # 156, chunk: page_content='different iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the'
# --------------------------------------------
# chunk # 157, chunk: page_content='iterati ve cycles of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of'
# --------------------------------------------
# chunk # 158, chunk: page_content='of development.\nObjecti ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on'
# --------------------------------------------
# chunk # 159, chunk: page_content='ve: This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and'
# --------------------------------------------
# chunk # 160, chunk: page_content='This study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings'
# --------------------------------------------
# chunk # 161, chunk: page_content='study aimed to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and'
# --------------------------------------------
# chunk # 162, chunk: page_content='to determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements'
# --------------------------------------------
# chunk # 163, chunk: page_content='determine the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for'
# --------------------------------------------
# chunk # 164, chunk: page_content='the capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame'
# --------------------------------------------
# chunk # 165, chunk: page_content='capabilities, treatment preferences, and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and'
# --------------------------------------------
# chunk # 166, chunk: page_content='and motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and training\ncomponents.\nMethods: A'
# --------------------------------------------
# chunk # 167, chunk: page_content='motivators for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and training\ncomponents.\nMethods: A qualitati'
# --------------------------------------------
# chunk # 168, chunk: page_content='for the training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and training\ncomponents.\nMethods: A qualitati ve study'
# --------------------------------------------
# chunk # 169, chunk: page_content='training of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and training\ncomponents.\nMethods: A qualitati ve study including'
# --------------------------------------------
# chunk # 170, chunk: page_content='of older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and training\ncomponents.\nMethods: A qualitati ve study including expert'
# --------------------------------------------
# chunk # 171, chunk: page_content='older adults\nwith mNCD and the perspecti ves of individuals on training goals and settings and requirements for exergame and training\ncomponents.\nMethods: A qualitati ve study including expert focus'
# ...
# --------------------------------------------
# chunk # 12556, chunk: page_content='36602851\n©Patrick Manser , Manuela Adcock-Omlin, Eling D de Bruin. Originally published in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under'
# --------------------------------------------
# chunk # 12557, chunk: page_content='Manser , Manuela Adcock-Omlin, Eling D de Bruin. Originally published in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the'
# --------------------------------------------
# chunk # 12558, chunk: page_content=', Manuela Adcock-Omlin, Eling D de Bruin. Originally published in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati'
# --------------------------------------------
# chunk # 12559, chunk: page_content='Manuela Adcock-Omlin, Eling D de Bruin. Originally published in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve'
# --------------------------------------------
# chunk # 12560, chunk: page_content='Adcock-Omlin, Eling D de Bruin. Originally published in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve Commons'
# --------------------------------------------
# chunk # 12561, chunk: page_content='Eling D de Bruin. Originally published in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution'
# --------------------------------------------
# chunk # 12562, chunk: page_content='published in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati'
# --------------------------------------------
# chunk # 12563, chunk: page_content='in JMIR Serious Games (https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or'
# --------------------------------------------
# chunk # 12564, chunk: page_content='(https://g ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/),'
# --------------------------------------------
# chunk # 12565, chunk: page_content='ames.jmir .org),\n05.01.2023. This is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits'
# --------------------------------------------
# chunk # 12566, chunk: page_content='This is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib'
# --------------------------------------------
# chunk # 12567, chunk: page_content='is an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution,'
# --------------------------------------------
# chunk # 12568, chunk: page_content='an open-access article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and'
# --------------------------------------------
# chunk # 12569, chunk: page_content='article distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in'
# --------------------------------------------
# chunk # 12570, chunk: page_content='distrib uted under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any'
# --------------------------------------------
# chunk # 12571, chunk: page_content='under the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided'
# --------------------------------------------
# chunk # 12572, chunk: page_content='the terms of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the'
# --------------------------------------------
# chunk # 12573, chunk: page_content='of the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original'
# --------------------------------------------
# chunk # 12574, chunk: page_content='the Creati ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work,'
# --------------------------------------------
# chunk # 12575, chunk: page_content='ve Commons Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first'
# --------------------------------------------
# chunk # 12576, chunk: page_content='Attrib ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in'
# --------------------------------------------
# chunk # 12577, chunk: page_content='ution License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR'
# --------------------------------------------
# chunk # 12578, chunk: page_content='License\n(https://creati vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious'
# --------------------------------------------
# chunk # 12579, chunk: page_content='vecommons.or g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited.'
# --------------------------------------------
# chunk # 12580, chunk: page_content='g/licenses/by/4.0/), which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete'
# --------------------------------------------
# chunk # 12581, chunk: page_content='which permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic'
# --------------------------------------------
# chunk # 12582, chunk: page_content='permits unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information,'
# --------------------------------------------
# chunk # 12583, chunk: page_content='unrestricted use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink'
# --------------------------------------------
# chunk # 12584, chunk: page_content='use, distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the'
# --------------------------------------------
# chunk # 12585, chunk: page_content='distrib ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original'
# --------------------------------------------
# chunk # 12586, chunk: page_content='ution, and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication'
# --------------------------------------------
# chunk # 12587, chunk: page_content='and reproduction in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on'
# --------------------------------------------
# chunk # 12588, chunk: page_content='in any medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir'
# --------------------------------------------
# chunk # 12589, chunk: page_content='medium,\nprovided the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org,'
# --------------------------------------------
# chunk # 12590, chunk: page_content='the original work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this'
# --------------------------------------------
# chunk # 12591, chunk: page_content='work, first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and'
# --------------------------------------------
# chunk # 12592, chunk: page_content='first published in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license'
# --------------------------------------------
# chunk # 12593, chunk: page_content='in JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information'
# --------------------------------------------
# chunk # 12594, chunk: page_content='JMIR Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must'
# --------------------------------------------
# chunk # 12595, chunk: page_content='Serious Games, is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be'
# --------------------------------------------
# chunk # 12596, chunk: page_content='is properly cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR'
# --------------------------------------------
# chunk # 12597, chunk: page_content='cited. The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games'
# --------------------------------------------
# chunk # 12598, chunk: page_content='The complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 |'
# --------------------------------------------
# chunk # 12599, chunk: page_content='complete bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol.'
# --------------------------------------------
# chunk # 12600, chunk: page_content='bibliographic information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 |'
# --------------------------------------------
# chunk # 12601, chunk: page_content='information, a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23'
# --------------------------------------------
# chunk # 12602, chunk: page_content='a\nlink to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g'
# --------------------------------------------
# chunk # 12603, chunk: page_content='to the original publication on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir'
# --------------------------------------------
# chunk # 12604, chunk: page_content='on https://g ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number'
# --------------------------------------------
# chunk # 12605, chunk: page_content='ames.jmir .org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for'
# --------------------------------------------
# chunk # 12606, chunk: page_content='.org, as well as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation'
# --------------------------------------------
# chunk # 12607, chunk: page_content='as this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et'
# --------------------------------------------
# chunk # 12608, chunk: page_content='this copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al'
# --------------------------------------------
# chunk # 12609, chunk: page_content='copyright and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al JMIR'
# --------------------------------------------
# chunk # 12610, chunk: page_content='and license information must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al JMIR SERIOUS'
# --------------------------------------------
# chunk # 12611, chunk: page_content='must be included.\nJMIR Serious Games 2023 | vol. 11 | e37616 | p. 23 https://g ames.jmir .org/2023/1/e37616\n(page number not for citation purposes)Manser et al JMIR SERIOUS GAMES\nXSL•FO\nRenderX'
# --------------------------------------------
